# %% [markdown]
# Setup new GIT integration

# %%
%%sql -r dataframe_1
use role accountadmin;

# %%
%%sql -r dataframe_2
create or replace api integration github_mbenicio1909
    api_provider = git_https_api
    api_allowed_prefixes = ('https://github.com/mbenicio1909')
    enabled = true
    allowed_authentication_secrets = all
    -- comment='<comment>';
